# %%
from utils import *

# %%
# Usage example
log_dirs = ["output/v1/logs/validation", "output/v2/logs/validation"]
labels = ["GOOG simpel", "GOOG multimodal"]
fig = plot_multiple_training_runs(log_dirs, labels)
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\paul-\anaconda3\envs\ml_angew_programm\lib\site-packages\tensorflow\python\summary\summary_iterator.py:31: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
from utils import *

# %%
# Usage example
log_dirs = ["output/v3/logs/validation", "output/v4/logs/validation"]
labels = ["Tech-Mix simpel", "Tech-Mix multimodal"]
fig = plot_multiple_training_runs(log_dirs, labels)
plt.show()

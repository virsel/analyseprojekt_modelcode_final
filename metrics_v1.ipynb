# %%
import __init__
import os
import ast  # for safely evaluating string representations of lists
from pathlib import Path
import tensorflow as tf
from data import load_data
from utils import comp_metrics, describe_model_architecture
import numpy as np
import json

# %%
version = 'v1'
dir_path = '.'
data_path = str(Path(dir_path) /  'input/stocks_step4.csv')
output_path = str(Path(dir_path) /  f'output/{version}')
model_path = str(Path(output_path) /  'model')

# %%
# Daten laden
_, _, test_data = load_data(data_path, window_size=30, only_goog=True)

# %%
# Load the saved model
loaded_model = tf.keras.models.load_model(model_path)

# %%
# Print layer details
print(json.dumps(describe_model_architecture(loaded_model), indent=2))
# Out:
# [
#   {
#     "name": "lstm_2",
#     "type": "LSTM",
#     "units": 128
#   },
#   {
#     "name": "dropout_2",
#     "type": "Dropout",
#     "dropout_rate": 0.2
#   },
#   {
#     "name": "lstm_3",
#     "type": "LSTM",
#     "units": 64
#   },
#   {
#     "name": "dropout_3",
#     "type": "Dropout",
#     "dropout_rate": 0.1
#   },
#   {
#     "name": "dense_2",
#     "type": "Dense",
#     "units": 64
#   },
#   {
#     "name": "dense_3",
#     "type": "Dense",
#     "units": 1
#   }
# ]

# %%
for i in range(len(test_data)):
    stock_testd = test_data[i]
    scaler = stock_testd['scaler']
    stock_name = stock_testd['stock']
    df = stock_testd['df']
    
    X = []
    y = []
    for i in range(len(stock_testd['test_data'])):
        data = stock_testd['test_data'][i]
        X.append(data[0])
        y.append(data[1])
        
    X = np.array(X)
    y = np.array(y)
    
    print(f'Predicting {stock_name}...')
    y_pred = loaded_model.predict(X)
    print(f'Metrics for {stock_name}')
    comp_metrics(scaler, y, y_pred, df)
# Out:
# Predicting GOOG...
# Metrics for GOOG
# Mean Absolute Error (MAE): 14.78083610534668
# Mean Squared Error (MSE): 356.99383544921875
# Mean Absolute Percentage Error (MAPE): 2.05%
